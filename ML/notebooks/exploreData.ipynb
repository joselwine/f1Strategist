# %%
from pathlib import Path
import sys
import os
import pandas as pd

# adjust filename if yours is different
df = pd.read_csv("../data/processed/laps_multiyear_full.csv")

print("Shape:", df.shape)
print("\nColumns:")
for c in df.columns:
    print("-", c)

df.head()

#Show where we are
print("Working directory:", os.getcwd())

# Project root is the parent of "notebooks"
PROJECT_ROOT = Path.cwd().parents[0]
print("PROJECT_ROOT:", PROJECT_ROOT)

# Add project root to Python path (so `src` is visible)
sys.path.append(str(PROJECT_ROOT))

# Now imports from src.* work
from src.config import PROCESSED_DIR

print("PROCESSED_DIR:", PROCESSED_DIR)

# List files in data/processed
from pathlib import Path
list(PROCESSED_DIR.iterdir())
# Out:
# Shape: (72540, 16)
#
# Columns:
# - Year
# - Track
# - RaceId
# - Driver
# - Team
# - LapNumber
# - LapNumberNorm
# - LapTime_s
# - Stint
# - LapsSinceLastPit
# - StopsSoFar
# - Compound
# - TyreLife
# - Position
# - TrackStatus
# - is_pit_lap
# Working directory: C:\Users\Josel\Dissertation\ML\notebooks
# PROJECT_ROOT: C:\Users\Josel\Dissertation\ML
# PROCESSED_DIR: C:\Users\Josel\Dissertation\ML\data\processed
# [WindowsPath('C:/Users/Josel/Dissertation/ML/data/processed/laps_2023_full.csv'),
#  WindowsPath('C:/Users/Josel/Dissertation/ML/data/processed/laps_2023_train_basic.csv'),
#  WindowsPath('C:/Users/Josel/Dissertation/ML/data/processed/laps_multiyear_full.csv')]

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()

print("\nDirectory contents:")
for item in PROJECT_ROOT.iterdir():
    print(" -", item)
# Out:
# Directory contents:
#  - C:\Users\Josel\Dissertation\ML\notebooks\.ipynb_checkpoints
#  - C:\Users\Josel\Dissertation\ML\notebooks\buildLapDataset.ipynb
#  - C:\Users\Josel\Dissertation\ML\notebooks\exploreData.ipynb
#  - C:\Users\Josel\Dissertation\ML\notebooks\pitPrediction.ipynb

# %%
df = pd.read_csv(out_path)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(out_path)
#       2 print(df.shape)
#       3 df.head()
#
# NameError: name 'pd' is not defined
